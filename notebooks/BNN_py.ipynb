# %%
import keras
import larq
model = tf.keras.models.Sequential(
    [
        tf.keras.layers.Flatten(),
        larq.layers.QuantDense(
            10000, kernel_quantizer="ste_sign", kernel_constraint="weight_clip"
        ),
        larq.layers.QuantDense(
        1000,
        kernel_quantizer="ste_sign",
        kernel_constraint="weight_clip",
        ),
        larq.layers.QuantDense(
            21,
            input_quantizer="ste_sign",
            kernel_quantizer="ste_sign",
            kernel_constraint="weight_clip",
            activation="softmax",
        ),
    ]
)

# %%
import pandas as pd
aa_embeddings = pd.read_csv("../data/amino_acid_embeddings.csv")
AA = aa_embeddings.protein_ID
aa_embeddings.head()
# Out:
#   protein_ID         0         1         2         3         4         5  \
# 0          R -0.059950 -0.021298  0.011929  0.212553  0.090613 -0.205165
# 1          H -0.056079  0.057042 -0.244368  0.067978 -0.091491 -0.204949
# 2          K -0.131090  0.107712  0.051131  0.358813  0.282009 -0.324377
# 3          D -0.123390  0.108910 -0.207840  0.443987  0.252411 -0.097798
# 4          E  0.048177  0.070474 -0.184724  0.410544  0.085891 -0.143633
#
#           6         7         8  ...      1270      1271      1272      1273  \
# 0 -0.195593  0.188544 -0.178643  ... -0.233565 -0.074078 -0.030072  0.274070
# 1 -0.334344  0.308644 -0.141353  ... -0.188578 -0.110628 -0.274257  0.288630
# 2 -0.202239  0.193155 -0.079613  ... -0.039915 -0.063954 -0.247402  0.225384
# 3 -0.030466  0.032946  0.043423  ...  0.160122 -0.273841 -0.137451  0.260009
# 4 -0.132035  0.013654 -0.149871  ...  0.006640 -0.099402 -0.220248  0.139529
#
#        1274      1275      1276      1277      1278      1279
# ...
